# %%
import datetime
import pandas as pd
from datetime import datetime, timedelta
from xtquant import xtdatacenter as xtdc
from xtquant import xtdata
#from read_data import get_market_data
from cook_data import cook_data, get_singel_market_data, get_main_data
from pocess_order import OrderManager

xtdc.set_token('4065054877ce5724155dbc5bcba200381ce5eb35')
xtdc.init()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 7
#       5 from xtquant import xtdata
#       6 #from read_data import get_market_data
# ----> 7 from cook_data import cook_data, get_singel_market_data, get_main_data
#       8 from pocess_order import OrderManager
#      10 xtdc.set_token('4065054877ce5724155dbc5bcba200381ce5eb35')
#
# ImportError: cannot import name 'get_singel_market_data' from 'cook_data' (c:\Users\Administrator\Desktop\新建文件夹\branches\Liang\work_space-main\cook_data.py)

# %%
from read_data import get_main_contract_code

# %%
def get_main_contract_code(continuous_contract_code: str, start_time: str, end_time: str)-> str:
    start_time_dt = datetime.strptime(start_time, '%Y%m%d')
    dt = start_time_dt - timedelta(days=30)
    dt_str = dt.strftime('%Y%m%d')
    print(dt_str)
    main_df = get_singel_market_data(continuous_contract_code, 'historymaincontract', start_time=dt_str, end_time=end_time, count=-1)[['time','合约在交易所的代码']]

    main_df.columns = ['time','code']        
    main_df['time'] = pd.to_datetime(main_df['time'], unit='ms')
    main_df["time"] = main_df["time"] + pd.Timedelta(hours=8)#转为北京时区
    main_df["time"] = main_df['time'].dt.strftime('%Y%m%d')#将Y-m-d变为Ymd

    main_contract = main_df[main_df['time']< start_time].iloc[-1,1]  # 获取开始时间之前的最后一个主力合约代码
    main_contract = main_contract
    return main_contract

# %%
with open("./data/code.txt", "r") as f:
    codes = f.read().splitlines()
print(codes)
# Out:
# ['ag00.SF', 'al00.SF', 'ao00.SF', 'au00.SF', 'br00.SF', 'bu00.SF', 'cu00.SF', 'fu00.SF', 'hc00.SF', 'ni00.SF', 'pb00.SF', 'rb00.SF', 'ru00.SF', 'sn00.SF', 'sp00.SF', 'ss00.SF', 'wr00.SF', 'zn00.SF', 'a001.DF', 'b001.DF', 'bb00.DF', 'c001.DF', 'cs00.DF', 'eb00.DF', 'eg00.DF', 'fb00.DF', 'i001.DF', 'j001.DF', 'jd00.DF', 'jm00.DF', 'l001.DF', 'lg00.DF', 'lh00.DF', 'm001.DF', 'p001.DF', 'pg00.DF', 'pp00.DF', 'rr00.DF', 'v001.DF', 'y001.DF', 'AP00.ZF', 'CF00.ZF', 'CJ00.ZF', 'CY00.ZF', 'FG00.ZF', 'JR00.ZF', 'LR00.ZF', 'MA00.ZF', 'OI00.ZF', 'PF00.ZF', 'PK00.ZF', 'PM00.ZF', 'PR00.ZF', 'PX00.ZF', 'RI00.ZF', 'RM00.ZF', 'RS00.ZF', 'SA00.ZF', 'SF00.ZF', 'SH00.ZF', 'SM00.ZF', 'SR00.ZF', 'TA00.ZF', 'UR00.ZF', 'WH00.ZF', 'ZC00.ZF', 'lc00.GF', 'ps00.GF', 'si00.GF', 'sc00.INE']

# %%
main_contract_dict = {}
get_main_data('c001.DF' , '20241221', '20250301')
# for i in codes:
#     main_contract_dict[i] =  get_main_data(i , '20241221', '20250301')
# main_contract_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 main_contract_dict = {}
# ----> 2 get_main_data('c001.DF' , '20241221', '20250301')
#       3 # for i in codes:
#       4 #     main_contract_dict[i] =  get_main_data(i , '20241221', '20250301')
#       5 # main_contract_dict
#
# NameError: name 'get_main_data' is not defined

# %%
get_main_data('ao00.SF', '20250101', '20250301')
# Out:
# 20241202
# 'ao2502'

# %%
xtdata.get_option_detail_data('ao2507C3100.SF')
# Out:
# {'ExchangeID': 'SHFE',
#  'InstrumentID': 'ao2507C3100',
#  'InstrumentName': 'ao2507C3100',
#  'ProductID': 'ao_o',
#  'ProductType': 2,
#  'OpenDate': '20250305',
#  'CreateDate': '20250305',
#  'ExpireDate': '20250624',
#  'PreClose': 7.0,
#  'SettlementPrice': 9.5,
#  'UpStopPrice': 272.0,
#  'DownStopPrice': 0.5,
#  'LongMarginRatio': 0.0,
#  'ShortMarginRatio': 0.0,
#  'PriceTick': 0.5,
#  'VolumeMultiple': 20,
#  'MaxMarketOrderVolume': 30,
#  'MinMarketOrderVolume': 1,
#  'MaxLimitOrderVolume': 100,
#  'MinLimitOrderVolume': 1,
#  'OptUnit': 20.0,
#  'MarginUnit': 1.7976931348623157e+308,
#  'OptUndlCode': 'ao2507',
#  'OptUndlMarket': 'SF',
#  'OptUndlCodeFull': 'ao2507.SF',
#  'OptExercisePrice': 3100.0,
#  'NeeqExeType': 2147483647,
#  'OptUndlRiskFreeRate': 0.0165,
#  'OptUndlHistoryRate': 0.2654,
#  'EndDelivDate': '20250305',
#  'optType': 'CALL',
#  'ProductCode': 'ao.SF'}

# %%
code = 'TA2509P4500.ZF'  # 示例期货代码
start_date = '20250604'
end_date = '20250613'

# %%
A = get_market_data([code], '1m', start_date, end_date, -1)[code]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 A = get_market_data([code], '1m', start_date, end_date, -1)[code]
#
# TypeError: get_market_data() takes from 2 to 4 positional arguments but 5 were given

# %%
option_list_PUT = xtdata.get_option_list(undl_code=code,dedate=start_date,opttype='PUT')
option_list_CALL = xtdata.get_option_list(undl_code=code,dedate=start_date,opttype='CALL')
# Out:
# ***** xtdata连接成功 *****
# 服务信息: {'tag': 'xtquant', 'version': '1.0'}
# 服务地址: 127.0.0.1:58609
# 数据路径: c:\Users\HP\Desktop\project\branches\Liang\work_space-main\data\datadir
# 设置xtdata.enable_hello = False可隐藏此消息

# %%
class StrategyManager:
    def __init__(self, order_manager):
        self.order_manager = order_manager

    def parse_option_code(self,option_code):
    
        code  = option_code.split('.')[0]
        if '-' in code:
            parts = code.split('-')
            if len(parts) == 3:
                underlying = parts[0]
                option_type = 'call' if parts[1].upper() == 'C' else 'put'
                strike = int(parts[2])
            else:
                import traceback
                traceback.print_exc()

        else:

            call_pos = code.find('C') # 找不到指定字符串的时候返回 -1
            put_pos = code.find('P')

            if call_pos != -1:
                option_type = 'call'
                underlying = code[:call_pos]
                strike = int(code[call_pos + 1:])
            elif put_pos != -1:
                option_type = 'put'
                underlying = code[:put_pos]
                strike = int(code[put_pos + 1:])
            else:
                import traceback
                traceback.print_exc()

        return {
            'option_type': option_type,
            'underlying': underlying,
            'strike': strike,
            'exchange': option_code.split('.')[-1] if '.' in option_code else None
        }
    
    def filter_options(self, option_dict):
        # 按值分组
        value_groups = {}
        for key, value in option_dict.items():
            if value not in value_groups:
                value_groups[value] = []
            value_groups[value].append(key)
        
        # 对每个值组，选择最短的键
        filtered_dict = {}
        for value, keys in value_groups.items():
            # 找到最短的键（如果有多个相同长度，取第一个）
            shortest_key = min(keys, key=len)
            filtered_dict[shortest_key] = value
        
        return filtered_dict
    
    def cal_lot_size(self, code: str, basic_lot: int, lookback_days: int) -> int:
        pass

    def strategy(self, code: str, start_date: str, end_date: str, max_signals: int = 30, lookback_days: int = 20, k: float = 0.08, close_n: int = 10, alarm_ratio: float = 0.02) -> pd.DataFrame:
        #max_signals:该日积累该次数信号开仓，lookback_days:回溯窗口期大小，k：ratio of option's K and future price, close_n:于行权日前n天平仓
        future_dict = get_market_data(codes=[code], period='1m', start_time=start_date, end_time=end_date, count=-1)
        future_df = cook_data(raw_data=future_dict[code])[['date', 'close', 'trading_date']].copy()
        end_trading_date_str = future_df.iloc[-1]['date'].date().strftime('%Y%m%d')
        
        signal_count_pos = 0
        signal_count_neg = 0
        
        # 初始化列
        future_df['signal_type'] = 0
        future_df['close_min'] = 0.0
        future_df['close_max'] = 0.0
        
        price_dict = {}
        rows_to_drop = []
        option_dict = {}
        option_df = []

        # 获取当前期货对应的期权列表
        #option_list_PUT = xtdata.get_option_list(undl_code=code,dedate=start_date,opttype='PUT')
        #option_list_CALL = xtdata.get_option_list(undl_code=code,dedate=start_date,opttype='CALL')
        
        for i in range(len(future_df)):
            #----------------------------------------获取当前数据----------------------------------------
            current_time = future_df.iloc[i]['date']
            current_time_str = current_time.strftime('%Y%m%d%H%M%S')
            current_date = current_time.date()
            current_date_str = current_date.strftime('%Y%m%d')
            current_close = future_df.iloc[i]['close']
            current_trading_date = future_df.iloc[i]['trading_date']
            #print('获取数据完成！')

            #----------------------------------------生成交易信号----------------------------------------
            count = 0
            
            if count == 0:
                yesterday = current_date
                count += 1

            close_min = None
            close_max = None
            
            cache_key = current_trading_date
            
            if cache_key in price_dict:
                close_min = price_dict[cache_key]['close_min']
                close_max = price_dict[cache_key]['close_max']
                future_df.at[i, 'close_min'] = close_min
                future_df.at[i, 'close_max'] = close_max
            else:
                try:
                    dict_data = get_market_data([code], '1d', '', current_trading_date, lookback_days)
                    
                    if code in dict_data and not dict_data[code].empty:
                        close_min = dict_data[code]['close'].min()
                        close_max = dict_data[code]['close'].max()
                        future_df.at[i, 'close_min'] = close_min
                        future_df.at[i, 'close_max'] = close_max
                        price_dict[cache_key] = {'close_min': close_min, 'close_max': close_max}
                    else:
                        print(f"无法获取交易时间 {current_time} 的历史数据，标记删除行 {i}")
                        rows_to_drop.append(i)
                        continue
                        
                except Exception as e:
                    print(f"获取数据错误: {e}，标记删除行 {i}")
                    rows_to_drop.append(i)
                    continue
            
            if close_min is None or close_max is None:
                print(f"行 {i} 数据无效，标记删除")
                rows_to_drop.append(i)
                continue
            
            if current_close > close_max:
                signal_count_pos += 1
                signal_count_neg = 0  
                
            elif current_close < close_min:
                signal_count_neg += 1
                signal_count_pos = 0  

            if signal_count_pos >= max_signals:
                future_df.at[i, 'signal_type'] = 1
                # print(f"触发卖出PUT信号，交易时间: {current_date}, 价格: {current_close:.2f}")
                signal_count_pos = 0
                
            if signal_count_neg >= max_signals:
                future_df.at[i, 'signal_type'] = -1
                # print(f"触发卖出CALL信号，交易时间: {current_date}, 价格: {current_close:.2f}")
                signal_count_neg = 0

            if yesterday != current_date:
                signal_count_pos = 0
                signal_count_neg = 0

            yesterday = current_date
            #print('生成交易信号完成！')
            #-------------------------------------------------------------------------------------------


            #-----------------------------------------开仓模块-------------------------------------------
            # 开仓逻辑：若每天分钟级价格大于前lookback_days的max price次数超过max_signals（min同理），且当前持仓为空，则进行开仓
            # sell put signal
            if future_df.at[i, 'signal_type'] == 1 and self.order_manager.open_orders == {}:
                
                # 筛选出合适的期权
                strike_obj = current_close * (1 - k)
                option_info_dict = {}
                for option in option_list_PUT:
                    strike = self.parse_option_code(option)['strike']
                    # 取远端期权
                    if strike >= strike_obj:
                        option_info_dict[option] = strike

                # 对于一些期权，可能会有多个代码，这里进行筛选，例如SH2509.ZF和SH509.ZF
                option_info_dict = self.filter_options(option_info_dict)
                # 按照行权价从小到大排序，找出距离最近的远端期权
                option_info_dict = dict(sorted(option_info_dict.items(), key=lambda x: x[1], reverse=False))

                if option_info_dict:
                    selected_option = list(option_info_dict.keys())[0]
                    selected_strike = option_info_dict[selected_option]

                    # 获取当前期权的信息
                    selected_option_info = xtdata.get_option_detail_data(selected_option)
                    end_deliv_date = selected_option_info['EndDelivDate']
                    end_deliv_date = datetime.strptime(end_deliv_date, '%Y%m%d').date()
                    
                    # 更新当前期权的分钟级数据
                    if option_dict == {}:
                        option_dict = get_market_data(codes=[selected_option], period='1m', start_time=start_date, end_time=end_date, count=-1)
                        option_df = option_dict[selected_option]

                    print(f"选择的期权: {selected_option}, 类型: PUT, 行权价: {selected_strike}, OpenDate: {current_date}, EndDelivDate: {end_deliv_date}")
                    
                    # 获取当前期权的最新价格
                    current_option_price = option_df.iloc[i]['close']

                    # Sell Put
                    short_order = self.order_manager.open_order(
                        code=selected_option,  # 使用选择的期权代码
                        position=-1,
                        price=current_option_price,
                        open_future_price = current_close,
                        open_time=current_time,
                        lot=1,
                        slip=0.0
                    )
                    print(f"开仓: {short_order}, 时间: {current_time}")
                else:
                    print(f"在{current_time}没有找到满足条件的期权")

            # sell call signal
            if future_df.at[i, 'signal_type'] == -1 and self.order_manager.open_orders == {}:
                # 筛选出合适的期权
                strike_obj = current_close * (1 + k)
                option_info_dict = {}
                for option in option_list_CALL:
                    strike = self.parse_option_code(option)['strike']
                    # 取远端期权
                    if strike <= strike_obj:
                        option_info_dict[option] = strike

                # 对于一些期权，可能会有多个代码，这里进行筛选，例如SH2509.ZF和SH509.ZF
                option_info_dict = self.filter_options(option_info_dict)
                # 按照行权价从大到小排序，找出距离最近的远端期权
                option_info_dict = dict(sorted(option_info_dict.items(), key=lambda x: x[1], reverse=True))
                print(f"筛选出的期权: {option_info_dict}")
                if option_info_dict:
                    selected_option = list(option_info_dict.keys())[0]
                    selected_strike = option_info_dict[selected_option]

                    # 获取当前期权的信息
                    selected_option_info = xtdata.get_option_detail_data(selected_option)
                    end_deliv_date = selected_option_info['EndDelivDate']
                    end_deliv_date = datetime.strptime(end_deliv_date, '%Y%m%d').date()

                    # 更新当前期权的分钟级数据
                    if option_dict == {}:
                        option_dict = get_market_data(codes=[selected_option], period='1m', start_time=start_date, end_time=end_date, count=-1)
                        option_df = option_dict[selected_option]
                    
                    print(f"选择的期权: {selected_option}, 类型: CALL, 行权价: {selected_strike}, OpenDate: {current_date}, EndDelivDate: {end_deliv_date}")
                    
                    # 获取当前期权的最新价格
                    current_option_price = option_df.iloc[i]['close']

                    # Sell Call
                    short_order = self.order_manager.open_order(
                        code=selected_option,  # 使用选择的期权代码
                        position=-1,
                        price=current_option_price,
                        open_future_price = current_close,
                        open_time=current_time,
                        lot=1,
                        slip=0.0
                    )
                    print(f"开仓: {short_order}, 时间: {current_time}")
                else:
                    print(f"在{current_time}没有找到满足条件的期权")
            #-------------------------------------------------------------------------------------------


            #-----------------------------------------平仓模块-------------------------------------------
            # 平仓逻辑：如果价格达到预警价格，或者日期达到在行权日前close_n天，进行平仓
            if self.order_manager.open_orders != {}:
                for order_id, order_info in list(self.order_manager.open_orders.items()):
                    #print(order_info)
                    open_date = order_info['open_time'].date()
                    open_future_price = order_info['open_future_price']

                    # 获取当前期权的最新价格
                    current_option_price = option_df.iloc[i]['close']
                        
                    day_to_open = (current_date - open_date).days # 目前距离开仓日的天数
                    deliv_to_open = (end_deliv_date - open_date).days # 交割日距离开仓日的天数
                    dynamic_alarm_ratio = alarm_ratio + (day_to_open / deliv_to_open) * 0.08  # 动态调整预警比例,time越长，预警比例越高

                    if self.parse_option_code(order_info['code'])['option_type'] == 'call':
                        alarm_price = open_future_price * (1 + dynamic_alarm_ratio)
                        print(f"预警价格: {alarm_price:.2f} (CALL), open_future_price: {open_future_price:.2f}, day_to_open: {day_to_open}, deliv_to_open: {deliv_to_open}, dynamic_alarm_ratio: {dynamic_alarm_ratio:.2f}")
                        print(f"当前价格: {current_close:.2f} (CALL)")
                        #print(f"day_to_open: {day_to_open} ,deliv_to_open - close_n: {deliv_to_open-close_n}")
                        print(f"当前日期: {current_date_str}, 结束日期: {end_trading_date_str}")
                        if current_close >= alarm_price or day_to_open >= (deliv_to_open - close_n) or current_date_str == end_trading_date_str:
                            self.order_manager.close_order(
                                order_id=order_id,
                                price=current_option_price,
                                close_time=current_time
                            )
                            print(f"平仓: {order_id}, 时间: {current_time}, 价格: {current_close:.2f}")
                            return future_df

                    elif self.parse_option_code(order_info['code'])['option_type'] == 'put':
                        alarm_price = open_future_price * (1 - dynamic_alarm_ratio)

                        if current_close <= alarm_price or day_to_open >= (deliv_to_open - close_n) or current_date_str == end_trading_date_str:
                            self.order_manager.close_order(
                                order_id=order_id,
                                price=current_option_price,
                                close_time=current_time
                            )
                            print(f"平仓: {order_id}, 时间: {current_time}, 价格: {current_close:.2f}")
                            return future_df
            #-------------------------------------------------------------------------------------------

# %%
if __name__ == '__main__':
    # 示例用法
    order_manager = OrderManager(
                    initial_capital=100000,
                    contract_size=20,
                    margin_rate=0.0,
                    max_position_ratio=1,
                    fee_per_lot=8,
                    slip_rate=0.0
                )
    strategy_manager = StrategyManager(order_manager)
    
    code = 'SH2509.ZF'  # 示例期货代码
    start_date = '20250401'
    end_date = '20250601'
    
    
    strategy_manager.strategy(code=code, start_date=start_date, end_date=end_date, max_signals=30, lookback_days=20, k=0.08, close_n=10, alarm_ratio=0.02)
# Out:
# 数据解析完成: 13477 条有效数据
# 筛选出的期权: {'SH509C2840.ZF': 2840, 'SH509C2800.ZF': 2800, 'SH509C2760.ZF': 2760, 'SH509C2720.ZF': 2720, 'SH509C2680.ZF': 2680, 'SH509C2640.ZF': 2640, 'SH509C2600.ZF': 2600, 'SH509C2560.ZF': 2560, 'SH509C2520.ZF': 2520, 'SH509C2480.ZF': 2480, 'SH509C2440.ZF': 2440, 'SH509C2400.ZF': 2400}
# 选择的期权: SH509C2840.ZF, 类型: CALL, 行权价: 2840, OpenDate: 2025-04-01, EndDelivDate: 2025-08-13
# 开仓: 000001, 时间: 2025-04-01 10:04:00
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2635.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2636.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2638.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2638.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2638.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2638.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2632.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2631.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2630.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2632.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2635.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2634.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2636.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2638.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2638.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2647.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2659.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2658.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2658.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2658.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2658.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2659.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2659.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2659.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2663.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2670.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2667.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2672.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2675.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2671.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2670.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2668.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2668.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2668.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2666.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2664.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2665.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2664.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2663.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2661.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2660.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2660.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2658.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2659.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2659.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2654.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2638.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2638.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2638.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2636.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2636.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2633.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2635.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2633.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2632.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2633.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2633.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2631.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2635.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2636.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2637.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2639.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2642.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2642.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2645.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2645.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2642.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2642.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2639.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2644.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2642.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2642.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2639.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2642.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2639.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2639.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2639.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2640.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2641.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2643.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2644.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2645.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2644.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2644.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2645.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2645.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2644.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2644.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2644.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2645.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2645.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2645.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2647.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2647.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2659.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2658.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2657.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2656.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2651.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2655.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2687.70 (CALL), open_future_price: 2635.00, day_to_open: 0, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2653.00 (CALL)
# 当前日期: 20250401, 结束日期: 20250530
# 预警价格: 2689.27 (CALL), open_future_price: 2635.00, day_to_open: 1, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2649.00 (CALL)
# 当前日期: 20250402, 结束日期: 20250530
# 预警价格: 2689.27 (CALL), open_future_price: 2635.00, day_to_open: 1, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2652.00 (CALL)
# 当前日期: 20250402, 结束日期: 20250530
# 预警价格: 2689.27 (CALL), open_future_price: 2635.00, day_to_open: 1, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2650.00 (CALL)
# 当前日期: 20250402, 结束日期: 20250530
# 预警价格: 2689.27 (CALL), open_future_price: 2635.00, day_to_open: 1, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2647.00 (CALL)
# 当前日期: 20250402, 结束日期: 20250530
# 预警价格: 2689.27 (CALL), open_future_price: 2635.00, day_to_open: 1, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250402, 结束日期: 20250530
# 预警价格: 2689.27 (CALL), open_future_price: 2635.00, day_to_open: 1, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2647.00 (CALL)
# 当前日期: 20250402, 结束日期: 20250530
# 预警价格: 2689.27 (CALL), open_future_price: 2635.00, day_to_open: 1, deliv_to_open: 134, dynamic_alarm_ratio: 0.02
# 当前价格: 2648.00 (CALL)
# 当前日期: 20250402, 结束日期: 20250530
# ...
# 当前价格: 2448.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2450.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2446.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2446.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2447.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2447.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2449.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2449.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2447.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2446.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2446.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2447.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2445.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2446.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2438.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2438.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2438.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2439.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2434.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2434.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2430.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2429.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2431.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2432.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2430.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2427.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2429.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2429.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2431.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2432.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2431.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2430.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2426.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2429.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2429.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2426.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2427.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2427.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2425.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2422.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2421.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2423.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2421.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2422.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2425.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2425.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2426.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2422.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2421.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2422.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2420.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2416.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2419.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2421.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2418.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2419.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2420.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2419.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2419.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2418.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2417.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2419.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2418.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2418.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2418.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2418.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2421.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2420.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2422.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2421.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2421.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2421.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2423.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2425.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2425.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2429.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2426.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2427.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2426.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2425.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2425.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2425.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2426.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2425.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2422.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2422.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2778.94 (CALL), open_future_price: 2635.00, day_to_open: 58, deliv_to_open: 134, dynamic_alarm_ratio: 0.05
# 当前价格: 2423.00 (CALL)
# 当前日期: 20250529, 结束日期: 20250530
# 预警价格: 2780.51 (CALL), open_future_price: 2635.00, day_to_open: 59, deliv_to_open: 134, dynamic_alarm_ratio: 0.06
# 当前价格: 2424.00 (CALL)
# 当前日期: 20250530, 结束日期: 20250530
# 平仓: 000001, 时间: 2025-05-30 09:01:00, 价格: 2424.00

# %%
strategy_manager.order_manager.open_orders
# Out:
# {}

# %%
strategy_manager.order_manager.closed_orders
# Out:
# [{'order_id': '000001',
#   'code': 'SH509C2840.ZF',
#   'open_price': np.float64(67.0),
#   'open_future_price': np.float64(2635.0),
#   'open_time': Timestamp('2025-04-01 10:04:00'),
#   'position': -1,
#   'lot': 1,
#   'value': np.float64(1340.0),
#   'open_fee': 8,
#   'close_price': np.float64(15.0015),
#   'close_time': Timestamp('2025-05-30 09:01:00'),
#   'profit': np.float64(1039.97),
#   'fee': 16,
#   'net_profit': np.float64(1023.97),
#   'equity': np.float64(101023.97),
#   'holding_period': 1414.95}]
